# %%
import pandas as pd
import numpy as np
import os
mypath = "../mis_datasets"
main_path = "../datasets"

# %%
file = "01.csv"
df = pd.read_csv(os.path.join(mypath,file))
df.head()
# Out:
#    bar  20090101  a  1
# 0  bar  20090102  a  3
# 1  bar  20090103  a  5
# 2  bar  20090101  b  1
# 3  bar  20090102  b  3
# 4  bar  20090103  b  5

# %% [markdown]
# **parámetros varios de read_csv**

# %%
df2 = pd.read_csv(os.path.join(mypath,file), sep=",", names=['bar', 'fecha', "uno", "dos"], 
                dtype={'dos':np.int64}, parse_dates=['fecha'], skiprows=0, header=0, 
                skip_blank_lines=True, na_filter=False)
df2.head()
# Out:
#    bar      fecha uno  dos
# 0  bar 2009-01-02   a    3
# 1  bar 2009-01-03   a    5
# 2  bar 2009-01-01   b    1
# 3  bar 2009-01-02   b    3
# 4  bar 2009-01-03   b    5

# %% [markdown]
# **colocar los nombres de las columnas, que a estos nombres los tengo en otro archivo**

# %%
#guardo los nombres de las columnas en un dataframe
cols = pd.read_csv(main_path + "/customer-churn-model/Customer Churn Columns.csv")
#convierto la columna a una lista:
cols_names = cols['Column_Names'].tolist()
#coloco al header en "none" y con names= le paso la lista anterior:
df2=pd.read_csv(main_path + "/customer-churn-model/Customer Churn Model.txt", header=None, names=cols_names)
df2.head()
# Out:
#        A               B          C         D           E           F  \
# 0  State  Account Length  Area Code     Phone  Int'l Plan  VMail Plan
# 1     KS             128        415  382-4657          no         yes
# 2     OH             107        415  371-7191          no         yes
# 3     NJ             137        415  358-1921          no          no
# 4     OH              84        408  375-9999         yes          no
#
#                G           H          I           J  ...          L  \
# 0  VMail Message    Day Mins  Day Calls  Day Charge  ...  Eve Calls
# 1             25  265.100000        110   45.070000  ...         99
# 2             26  161.600000        123   27.470000  ...        103
# 3              0  243.400000        114   41.380000  ...        110
# 4              0  299.400000         71   50.900000  ...         88
#
#             M           N            O             P          Q           R  \
# ...

# %% [markdown]
# **cargar un fichero con open**

# %%
df3 = open(main_path + "/customer-churn-model/Customer Churn Model.txt")

# %%
#con strip quito los caracteres en blanco al principio y final de la linea de texto
cols = df3.readline().strip().split(",")
n_cols = len(cols)

# %%
main_dict = {} #creo un diccionario vacío
#recorro cada columna de "cols", creando un diccionario en donde la key es el nombre
#de la columna y como valor una lista vacía:
for col in cols:
    main_dict[col] = []
main_dict
# Out:
# {'State': [],
#  'Account Length': [],
#  'Area Code': [],
#  'Phone': [],
#  "Int'l Plan": [],
#  'VMail Plan': [],
#  'VMail Message': [],
#  'Day Mins': [],
#  'Day Calls': [],
#  'Day Charge': [],
#  'Eve Mins': [],
#  'Eve Calls': [],
#  'Eve Charge': [],
#  'Night Mins': [],
#  'Night Calls': [],
#  'Night Charge': [],
#  'Intl Mins': [],
#  'Intl Calls': [],
#  'Intl Charge': [],
#  'CustServ Calls': [],
#  'Churn?': []}

# %%
#ahora recorro el archivo:
counter = 0
for line in df3:
    values = line.strip().split(",") #almaceno todos los valores de la fila
    #recorro las columnas:
    for i in range(len(cols)):
        main_dict[cols[i]].append(values[i]) #y agrego en cada "celda" su respetivo valor
    counter += 1
print("el dataset tiene %d fila y %d columnas"%(counter, n_cols))
# Out:
# el dataset tiene 3333 fila y 21 columnas

# %%
df4 = pd.DataFrame(main_dict)
df4.head()
# Out:
#   State Account Length Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS            128       415  382-4657         no        yes
# 1    OH            107       415  371-7191         no        yes
# 2    NJ            137       415  358-1921         no         no
# 3    OH             84       408  375-9999        yes         no
# 4    OK             75       415  330-6626        yes         no
#
#   VMail Message    Day Mins Day Calls Day Charge  ... Eve Calls Eve Charge  \
# 0            25  265.100000       110  45.070000  ...        99  16.780000
# 1            26  161.600000       123  27.470000  ...       103  16.620000
# 2             0  243.400000       114  41.380000  ...       110  10.300000
# 3             0  299.400000        71  50.900000  ...        88   5.260000
# 4             0  166.700000       113  28.340000  ...       122  12.610000
#
#    Night Mins Night Calls Night Charge  Intl Mins Intl Calls Intl Charge  \
# ...

# %%
df3.close()

# %% [markdown]
# * **al abrir un archivo en modo "w" éste pierde todo su contenido**
# * **utilizar el "a" (append) para abrirlo si se quiere agregar información al final**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **otro trabajo de lectura/escritura**

# %%
#creo el acceso al archivo original y al de salida:
infile = main_path + "/customer-churn-model/Customer Churn Model.txt"
outfile = main_path + "/customer-churn-model/my tab Customer Churn Model.txt"

# %%
counter = 0
with open(infile, "r") as infile1:
    with open(outfile, "w") as outfile1:
        for line in infile1:
            fields = line.strip().split(",")
            outfile1.write("\t".join(fields))
            outfile1.write("\n")
            counter += 1
print("se copiaron %d filas."%(counter))
# Out:
# se copiaron 3334 filas.

# %%
df4 = pd.read_csv(main_path + "/customer-churn-model/my tab Customer Churn Model.txt", sep="\t")
df4.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %% [markdown]
# ## leer datos desde una url

# %%
medals_url = "http://winterolympicsmedals.com/medals.csv"
medals_data = pd.read_csv(medals_url)
medals_data.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %% [markdown]
# ## leer ficheros xls xlsx

# %%
ruta=main_path + "/titanic/titanic3.xls"
titanic2 = pd.read_excel(ruta, sheets='titanic3')
titanic2.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...
