# %% [markdown]
# # Esta notebook es para la propagación de la afinidad, para analizar de qué forma el clustering asignó las etiquetas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn import datasets
from sklearn.preprocessing import MinMaxScaler

from sklearn.cluster import AffinityPropagation
from sklearn.datasets.samples_generator import make_blobs
from sklearn import metrics
from itertools import cycle
# %matplotlib inline

# %%
data = pd.read_csv('../datasets/wine/winequality-red.csv', sep=";")
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# ## hago una de estas gráficas, que están fantásticas

# %%
data_graf = data[['fixed acidity', 'residual sugar', 'chlorides', 'density', 'quality']]
sns.pairplot(data_graf, hue='quality',height=4,kind='scatter')

# %% [markdown]
# **aquí aplico un min_max_sacler**

# %%
df_norm = data
scaler = MinMaxScaler()
scaler.fit_transform(df_norm)
# Out:
# array([[0.24778761, 0.39726027, 0.        , ..., 0.13772455, 0.15384615,
#         0.4       ],
#        [0.28318584, 0.52054795, 0.        , ..., 0.20958084, 0.21538462,
#         0.4       ],
#        [0.28318584, 0.43835616, 0.04      , ..., 0.19161677, 0.21538462,
#         0.4       ],
#        ...,
#        [0.15044248, 0.26712329, 0.13      , ..., 0.25149701, 0.4       ,
#         0.6       ],
#        [0.11504425, 0.35958904, 0.12      , ..., 0.22754491, 0.27692308,
#         0.4       ],
#        [0.12389381, 0.13013699, 0.47      , ..., 0.19760479, 0.4       ,
#         0.6       ]])

# %% [markdown]
# **lo elevo a la potencia, para eliminar cualquier negativo**

# %%
df_norm = df_norm**2

# %% [markdown]
# # KMeans
#
# * lo creo para luego realizar el AffinityPropagation

# %%
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(df_norm)
    wcss.append(kmeans.inertia_)

# %%
plt.figure(figsize = (8,5))
plt.plot(range(1, 11), wcss, marker = 'o', linestyle = '--')
plt.xlabel('Numero de Clusters')
plt.ylabel('WCSS')
plt.title('Agrupamiento K-means')
plt.show()

# %%
model_k = KMeans(n_clusters=6, random_state=666)
model_k.fit(df_norm)
# Out:
# KMeans(n_clusters=6, random_state=666)

# %%
md_k = pd.Series(model_k.labels_)

# %% [markdown]
# **agrego las DOS labels al dataframe: el modelo hierarchy y el kmeans**

# %%
df_norm['labels_k'] = md_k

# %%
fig.set_size_inches(15,6) #seteo el tamaño
plt.hist(df_norm['labels_k'], color='olive') #seteo al 2do gráfico (ax[1])
plt.show()

# %% [markdown]
# **chequeo que tengo todos los datos en orden**

# %%
len(model_k.labels_)
# Out:
# 1599

# %% [markdown]
# # Propagación de la Afinidad

# %%
centers = [[1,1], [-1,-1], [1,-1]]
x, labels = make_blobs(n_samples=300, centers=centers, cluster_std=0.5, random_state=0)

# %%
af = AffinityPropagation(preference=-50, random_state=0).fit(x)

# %% [markdown]
# ## aquí calculo los centroides de los clusteres y llamo a la función que me devuelve los elementos más cercanos a cada centroide

# %%
centroides = model_k.cluster_centers_ #guardo la cantidad de centroides
df_aff = df_norm.copy()
df_aff.drop('labels_k', axis=1, inplace=True)
closest, _ = metrics.pairwise_distances_argmin_min(centroides, df_aff) #aplico el pairwise
closest #los visualizo
# Out:
# array([ 302,  967, 1079, 1400,  220,  700], dtype=int64)

# %%
df_norm.iloc[closest]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 302           68.89          0.497025       0.0144            6.76   0.008464
# 967           72.25          0.435600       0.0400            4.41   0.009409
# 1079          62.41          0.090000       0.4624           68.89   0.002500
# 1400          62.41          0.476100       0.0441            4.41   0.006400
# 220           60.84          0.115600       0.1369            4.00   0.006724
# 700          112.36          1.040400       0.1849            8.41   0.005776
#
#       free sulfur dioxide  total sulfur dioxide   density       pH  sulphates  \
# 302                144.00                 784.0  0.998800  12.3201     0.5184
# 967                529.00               12769.0  0.994667   9.7969     0.2304
# 1079              1406.25               77284.0  0.986367   9.0601     0.2601
# 1400              1089.00               19881.0  0.992414  10.5625     0.2601
# ...

# %%
# sb.pairplot(dataframe.dropna(), hue='categoria',size=4,vars=["op","ex","ag"],kind='scatter')
