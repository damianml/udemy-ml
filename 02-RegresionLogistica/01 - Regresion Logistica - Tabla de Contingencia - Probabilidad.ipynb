# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("../datasets/gender-purchase/Gender Purchase.csv")

# %%
df.head()
# Out:
#    Gender Purchase
# 0  Female      Yes
# 1  Female      Yes
# 2  Female       No
# 3    Male       No
# 4    Male      Yes

# %%
df.describe(include='all')
# Out:
#         Gender Purchase
# count      511      511
# unique       2        2
# top     Female      Yes
# freq       265      280

# %% [markdown]
# ## Tablas de contingencia:

# %%
contingencia = pd.crosstab(df['Gender'], df['Purchase'])
contingencia
# Out:
# Purchase   No  Yes
# Gender
# Female    106  159
# Male      125  121

# %%
contingencia.sum(axis = 1)
# Out:
# Gender
# Female    265
# Male      246
# dtype: int64

# %%
contingencia.sum(axis = 0)
# Out:
# Purchase
# No     231
# Yes    280
# dtype: int64

# %%
contigencia.astype("float").div(contingencia.sum(axis=1), axis=0)*100
# Out:
# Purchase         No        Yes
# Gender
# Female    40.000000  60.000000
# Male      50.813008  49.186992
